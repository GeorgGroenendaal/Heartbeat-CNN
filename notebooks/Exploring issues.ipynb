# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_pickle("splitted_samples.data")

# %%
data.head()
# Out:
#    patient beat_type  beat_position  \
# 0        0         N            189
# 1        0         N            425
# 2        0         N            659
# 3        0         N            889
# 4        0         N           1113
#
#                                                waves
# 0  [[-0.0004107794277811361, -0.00261239189352849...
# 1  [[-0.00045817705406357484, -0.0030930819806448...
# 2  [[-0.0007267636029973947, -0.00525875376475549...
# 3  [[-0.0006793659767149558, -0.00501505180905132...
# 4  [[-0.0009953501519312145, -0.00744022475762694...

# %%
patient1 = data[data["patient"] == 1]
patient1["beat_type"].value_counts()
# Out:
# N    1534
# A       1
# Name: beat_type, dtype: int64

# %%
patient38 = data[data["patient"] == 38]

# %%
patient38["beat_type"].value_counts()
# Out:
# N    2082
# V      64
# A       7
# F       1
# Name: beat_type, dtype: int64

# %%
plt.figure(figsize=(10,10))
for i in range(4):
    plt.subplot(2,2,i+1)

    plt.plot(patient38.iloc[i]["waves"])
    plt.title(patient38.iloc[i]["beat_type"])
